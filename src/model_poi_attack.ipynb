# %%
import torch
from torchvision import datasets, transforms
from torch import nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR

# %%
import torchvision
print(torchvision.__version__)
# Out:
# 0.5.0

# %%
training_set = datasets.EMNIST('./emnist_data', split="balanced", train=True, download=True,
           transform=transforms.Compose([
               transforms.ToTensor(),
               transforms.Normalize((0.1307,), (0.3081,))]))
train_loader = torch.utils.data.DataLoader(training_set, batch_size=128, shuffle=True)
test_loader = torch.utils.data.DataLoader(
    datasets.EMNIST('./emnist_data', split="balanced", train=False, transform=transforms.Compose([
               transforms.ToTensor(),
               transforms.Normalize((0.1307,), (0.3081,))
           ])), batch_size=100, shuffle=True)

# %%
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 20, 5, 1)
        self.conv2 = nn.Conv2d(20, 50, 5, 1)
        self.fc1 = nn.Linear(4*4*50, 500)
        self.fc2 = nn.Linear(500, 47)
    def forward(self, x):
        x = self.conv1(x)
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(x)
        x = x.view(-1, 4*4*50)
        x = self.fc1(x)
        x = self.fc2(x)
        return x
    def name(self):
        return 'lenet'

# %%
def train(model, device, train_loader, optimizer, criterion, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 40 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))


def test(model, device, test_loader, criterion):
    model.eval()
    test_loss = 0
    correct = 0
    
    class_correct = list(0. for i in range(47))
    class_total = list(0. for i in range(47))
    
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            #test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
            test_loss += criterion(output, target).item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
            
            for i in range(len(data)):
                label = target[i].item()
                #print(pred.size(), target.size(), (pred[:, 0] == target).size())
                class_correct[label] += (pred[:, 0] == target)[i].item()
                class_total[label] += 1

    test_loss /= len(test_loader.dataset)

    print('\n#### Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    for i in range(47):
        #print(i, 100 * class_correct[i], class_total[i])
        #print(class_correct, class_total)
        class_acc = 100 * class_correct[i] / class_total[i]
        print('Accuracy of {} : {}'.format(i, class_acc))

# %%
# parser.add_argument('--batch-size', type=int, default=64, metavar='N',
#                     help='input batch size for training (default: 64)')
# parser.add_argument('--test-batch-size', type=int, default=1000, metavar='N',
#                     help='input batch size for testing (default: 1000)')
# parser.add_argument('--epochs', type=int, default=14, metavar='N',
#                     help='number of epochs to train (default: 14)')
# parser.add_argument('--lr', type=float, default=1.0, metavar='LR',
#                     help='learning rate (default: 1.0)')
# parser.add_argument('--gamma', type=float, default=0.7, metavar='M',
#                     help='Learning rate step gamma (default: 0.7)')
# parser.add_argument('--no-cuda', action='store_true', default=False,
#                     help='disables CUDA training')
# parser.add_argument('--seed', type=int, default=1, metavar='S',
#                     help='random seed (default: 1)')
# parser.add_argument('--log-interval', type=int, default=10, metavar='N',
#                     help='how many batches to wait before logging training status')
# parser.add_argument('--save-model', action='store_true', default=False,
#                     help='For Saving the current Model')
#args = parser.parse_args()

torch.manual_seed(0)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
criterion = nn.CrossEntropyLoss().to(device)

model = LeNet().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

scheduler = StepLR(optimizer, step_size=1, gamma=0.98)
for epoch in range(1, 15 + 1):
    train(model, device, train_loader, optimizer, criterion, epoch)
    test(model, device, test_loader, criterion)
    scheduler.step()
# Out:
# Train Epoch: 1 [0/112800 (0%)]	Loss: 3.857660
# Train Epoch: 1 [5120/112800 (5%)]	Loss: 2.294549
# Train Epoch: 1 [10240/112800 (9%)]	Loss: 1.339071
# Train Epoch: 1 [15360/112800 (14%)]	Loss: 0.899396
# Train Epoch: 1 [20480/112800 (18%)]	Loss: 1.037374
# Train Epoch: 1 [25600/112800 (23%)]	Loss: 0.817912
# Train Epoch: 1 [30720/112800 (27%)]	Loss: 0.569463
# Train Epoch: 1 [35840/112800 (32%)]	Loss: 0.716683
# Train Epoch: 1 [40960/112800 (36%)]	Loss: 0.615538
# Train Epoch: 1 [46080/112800 (41%)]	Loss: 0.605870
# Train Epoch: 1 [51200/112800 (45%)]	Loss: 0.843841
# Train Epoch: 1 [56320/112800 (50%)]	Loss: 0.671640
# Train Epoch: 1 [61440/112800 (54%)]	Loss: 0.696597
# Train Epoch: 1 [66560/112800 (59%)]	Loss: 0.517329
# Train Epoch: 1 [71680/112800 (63%)]	Loss: 0.554445
# Train Epoch: 1 [76800/112800 (68%)]	Loss: 0.585346
# Train Epoch: 1 [81920/112800 (73%)]	Loss: 0.365213
# Train Epoch: 1 [87040/112800 (77%)]	Loss: 0.462892
# Train Epoch: 1 [92160/112800 (82%)]	Loss: 0.584058
# Train Epoch: 1 [97280/112800 (86%)]	Loss: 0.482227
# Train Epoch: 1 [102400/112800 (91%)]	Loss: 0.379295
# Train Epoch: 1 [107520/112800 (95%)]	Loss: 0.354729
# Train Epoch: 1 [112640/112800 (100%)]	Loss: 0.378650
#
# #### Test set: Average loss: 0.0050, Accuracy: 15806/18800 (84%)
#
# Accuracy of 0 : 77.0
# Accuracy of 1 : 40.75
# Accuracy of 2 : 79.25
# Accuracy of 3 : 94.75
# Accuracy of 4 : 89.0
# Accuracy of 5 : 85.5
# Accuracy of 6 : 88.5
# Accuracy of 7 : 96.5
# Accuracy of 8 : 87.0
# Accuracy of 9 : 96.75
# Accuracy of 10 : 95.25
# Accuracy of 11 : 96.0
# Accuracy of 12 : 91.75
# Accuracy of 13 : 94.5
# Accuracy of 14 : 97.0
# Accuracy of 15 : 77.25
# Accuracy of 16 : 93.0
# Accuracy of 17 : 95.25
# Accuracy of 18 : 62.5
# Accuracy of 19 : 90.75
# Accuracy of 20 : 92.0
# Accuracy of 21 : 67.25
# Accuracy of 22 : 94.25
# Accuracy of 23 : 96.0
# Accuracy of 24 : 47.0
# Accuracy of 25 : 96.0
# Accuracy of 26 : 90.25
# Accuracy of 27 : 93.25
# Accuracy of 28 : 85.75
# Accuracy of 29 : 94.75
# Accuracy of 30 : 92.25
# Accuracy of 31 : 91.0
# Accuracy of 32 : 97.75
# Accuracy of 33 : 92.0
# Accuracy of 34 : 74.5
# Accuracy of 35 : 94.75
# Accuracy of 36 : 88.5
# Accuracy of 37 : 91.25
# Accuracy of 38 : 94.75
# Accuracy of 39 : 92.0
# Accuracy of 40 : 35.25
# Accuracy of 41 : 55.5
# Accuracy of 42 : 92.5
# Accuracy of 43 : 86.75
# Accuracy of 44 : 23.0
# Accuracy of 45 : 86.0
# Accuracy of 46 : 79.0
# Train Epoch: 2 [0/112800 (0%)]	Loss: 0.442656
# Train Epoch: 2 [5120/112800 (5%)]	Loss: 0.327438
# Train Epoch: 2 [10240/112800 (9%)]	Loss: 0.495094
# Train Epoch: 2 [15360/112800 (14%)]	Loss: 0.510046
# Train Epoch: 2 [20480/112800 (18%)]	Loss: 0.422272
# Train Epoch: 2 [25600/112800 (23%)]	Loss: 0.628545
# Train Epoch: 2 [30720/112800 (27%)]	Loss: 0.536415
# Train Epoch: 2 [35840/112800 (32%)]	Loss: 0.448159
# Train Epoch: 2 [40960/112800 (36%)]	Loss: 0.504743
# Train Epoch: 2 [46080/112800 (41%)]	Loss: 0.328635
# Train Epoch: 2 [51200/112800 (45%)]	Loss: 0.411370
# Train Epoch: 2 [56320/112800 (50%)]	Loss: 0.368188
# Train Epoch: 2 [61440/112800 (54%)]	Loss: 0.398992
# Train Epoch: 2 [66560/112800 (59%)]	Loss: 0.362891
# Train Epoch: 2 [71680/112800 (63%)]	Loss: 0.466211
# Train Epoch: 2 [76800/112800 (68%)]	Loss: 0.475823
# Train Epoch: 2 [81920/112800 (73%)]	Loss: 0.362955
# Train Epoch: 2 [87040/112800 (77%)]	Loss: 0.546052
# Train Epoch: 2 [92160/112800 (82%)]	Loss: 0.352571
# Train Epoch: 2 [97280/112800 (86%)]	Loss: 0.271427
# Train Epoch: 2 [102400/112800 (91%)]	Loss: 0.442707
# Train Epoch: 2 [107520/112800 (95%)]	Loss: 0.478963
# Train Epoch: 2 [112640/112800 (100%)]	Loss: 0.350233
#
# #### Test set: Average loss: 0.0042, Accuracy: 16109/18800 (86%)
#
# Accuracy of 0 : 73.0
# Accuracy of 1 : 90.25
# Accuracy of 2 : 91.75
# Accuracy of 3 : 98.25
# Accuracy of 4 : 86.5
# Accuracy of 5 : 74.0
# Accuracy of 6 : 90.0
# Accuracy of 7 : 98.0
# Accuracy of 8 : 92.5
# Accuracy of 9 : 73.0
# Accuracy of 10 : 93.5
# Accuracy of 11 : 88.0
# Accuracy of 12 : 96.25
# Accuracy of 13 : 90.75
# Accuracy of 14 : 97.0
# Accuracy of 15 : 48.5
# Accuracy of 16 : 93.25
# Accuracy of 17 : 95.0
# Accuracy of 18 : 58.0
# Accuracy of 19 : 91.0
# Accuracy of 20 : 92.25
# Accuracy of 21 : 27.5
# Accuracy of 22 : 96.0
# Accuracy of 23 : 94.75
# Accuracy of 24 : 63.25
# Accuracy of 25 : 94.75
# Accuracy of 26 : 88.5
# Accuracy of 27 : 94.75
# Accuracy of 28 : 95.25
# Accuracy of 29 : 94.75
# Accuracy of 30 : 90.0
# Accuracy of 31 : 93.5
# Accuracy of 32 : 98.0
# Accuracy of 33 : 93.75
# Accuracy of 34 : 89.25
# Accuracy of 35 : 88.0
# Accuracy of 36 : 87.5
# Accuracy of 37 : 89.5
# Accuracy of 38 : 96.0
# Accuracy of 39 : 91.0
# Accuracy of 40 : 74.25
# Accuracy of 41 : 63.5
# Accuracy of 42 : 93.0
# Accuracy of 43 : 93.0
# Accuracy of 44 : 52.5
# Accuracy of 45 : 91.75
# Accuracy of 46 : 82.5
# Train Epoch: 3 [0/112800 (0%)]	Loss: 0.487697
# Train Epoch: 3 [5120/112800 (5%)]	Loss: 0.361672
# Train Epoch: 3 [10240/112800 (9%)]	Loss: 0.324277
# Train Epoch: 3 [15360/112800 (14%)]	Loss: 0.446292
# Train Epoch: 3 [20480/112800 (18%)]	Loss: 0.253455
# Train Epoch: 3 [25600/112800 (23%)]	Loss: 0.247162
# Train Epoch: 3 [30720/112800 (27%)]	Loss: 0.323871
# Train Epoch: 3 [35840/112800 (32%)]	Loss: 0.373129
# Train Epoch: 3 [40960/112800 (36%)]	Loss: 0.479081
# Train Epoch: 3 [46080/112800 (41%)]	Loss: 0.413809
# Train Epoch: 3 [51200/112800 (45%)]	Loss: 0.293431
# Train Epoch: 3 [56320/112800 (50%)]	Loss: 0.326470
# Train Epoch: 3 [61440/112800 (54%)]	Loss: 0.294591
# Train Epoch: 3 [66560/112800 (59%)]	Loss: 0.357266
# Train Epoch: 3 [71680/112800 (63%)]	Loss: 0.304585
# Train Epoch: 3 [76800/112800 (68%)]	Loss: 0.282961
# Train Epoch: 3 [81920/112800 (73%)]	Loss: 0.418482
# Train Epoch: 3 [87040/112800 (77%)]	Loss: 0.410434
# Train Epoch: 3 [92160/112800 (82%)]	Loss: 0.375797
# Train Epoch: 3 [97280/112800 (86%)]	Loss: 0.208971
# Train Epoch: 3 [102400/112800 (91%)]	Loss: 0.207290
# Train Epoch: 3 [107520/112800 (95%)]	Loss: 0.219855
# Train Epoch: 3 [112640/112800 (100%)]	Loss: 0.330556
#
# #### Test set: Average loss: 0.0040, Accuracy: 16227/18800 (86%)
#
# Accuracy of 0 : 69.0
# Accuracy of 1 : 65.75
# Accuracy of 2 : 80.25
# Accuracy of 3 : 96.0
# Accuracy of 4 : 89.25
# Accuracy of 5 : 86.5
# Accuracy of 6 : 95.25
# Accuracy of 7 : 97.75
# Accuracy of 8 : 88.25
# Accuracy of 9 : 66.0
# Accuracy of 10 : 97.5
# Accuracy of 11 : 92.75
# Accuracy of 12 : 91.25
# Accuracy of 13 : 91.75
# Accuracy of 14 : 98.25
# Accuracy of 15 : 37.75
# Accuracy of 16 : 94.0
# Accuracy of 17 : 97.25
# Accuracy of 18 : 59.25
# Accuracy of 19 : 91.5
# Accuracy of 20 : 95.5
# Accuracy of 21 : 52.0
# Accuracy of 22 : 96.25
# Accuracy of 23 : 94.5
# Accuracy of 24 : 60.5
# Accuracy of 25 : 94.75
# Accuracy of 26 : 89.75
# Accuracy of 27 : 98.0
# Accuracy of 28 : 85.75
# Accuracy of 29 : 91.75
# Accuracy of 30 : 92.75
# Accuracy of 31 : 91.0
# Accuracy of 32 : 97.75
# Accuracy of 33 : 93.75
# Accuracy of 34 : 89.0
# Accuracy of 35 : 96.0
# Accuracy of 36 : 91.5
# Accuracy of 37 : 89.25
# Accuracy of 38 : 96.0
# Accuracy of 39 : 97.25
# Accuracy of 40 : 83.5
# Accuracy of 41 : 64.25
# Accuracy of 42 : 91.5
# Accuracy of 43 : 89.75
# Accuracy of 44 : 62.75
# Accuracy of 45 : 94.0
# Accuracy of 46 : 92.75
# Train Epoch: 4 [0/112800 (0%)]	Loss: 0.331513
# Train Epoch: 4 [5120/112800 (5%)]	Loss: 0.307189
# Train Epoch: 4 [10240/112800 (9%)]	Loss: 0.304588
# Train Epoch: 4 [15360/112800 (14%)]	Loss: 0.413393
# Train Epoch: 4 [20480/112800 (18%)]	Loss: 0.225339
# Train Epoch: 4 [25600/112800 (23%)]	Loss: 0.276235
# Train Epoch: 4 [30720/112800 (27%)]	Loss: 0.461525
# Train Epoch: 4 [35840/112800 (32%)]	Loss: 0.347591
# Train Epoch: 4 [40960/112800 (36%)]	Loss: 0.366311
# Train Epoch: 4 [46080/112800 (41%)]	Loss: 0.262927
# Train Epoch: 4 [51200/112800 (45%)]	Loss: 0.413544
# Train Epoch: 4 [56320/112800 (50%)]	Loss: 0.353797
# Train Epoch: 4 [61440/112800 (54%)]	Loss: 0.397284
# Train Epoch: 4 [66560/112800 (59%)]	Loss: 0.314784
# Train Epoch: 4 [71680/112800 (63%)]	Loss: 0.298609
# Train Epoch: 4 [76800/112800 (68%)]	Loss: 0.175983
# Train Epoch: 4 [81920/112800 (73%)]	Loss: 0.459651
# Train Epoch: 4 [87040/112800 (77%)]	Loss: 0.354503
# Train Epoch: 4 [92160/112800 (82%)]	Loss: 0.358017
# Train Epoch: 4 [97280/112800 (86%)]	Loss: 0.281345
# Train Epoch: 4 [102400/112800 (91%)]	Loss: 0.332942
# Train Epoch: 4 [107520/112800 (95%)]	Loss: 0.282905
# Train Epoch: 4 [112640/112800 (100%)]	Loss: 0.668001
#
# #### Test set: Average loss: 0.0038, Accuracy: 16337/18800 (87%)
#
# Accuracy of 0 : 38.75
# Accuracy of 1 : 51.0
# Accuracy of 2 : 85.25
# Accuracy of 3 : 98.75
# Accuracy of 4 : 90.75
# Accuracy of 5 : 88.75
# Accuracy of 6 : 93.0
# Accuracy of 7 : 98.25
# Accuracy of 8 : 93.75
# Accuracy of 9 : 81.75
# Accuracy of 10 : 96.5
# Accuracy of 11 : 96.25
# Accuracy of 12 : 93.5
# Accuracy of 13 : 89.0
# Accuracy of 14 : 96.75
# Accuracy of 15 : 42.5
# Accuracy of 16 : 93.5
# Accuracy of 17 : 96.75
# Accuracy of 18 : 53.0
# Accuracy of 19 : 91.25
# Accuracy of 20 : 96.25
# Accuracy of 21 : 69.75
# Accuracy of 22 : 96.75
# Accuracy of 23 : 97.75
# Accuracy of 24 : 87.0
# Accuracy of 25 : 96.25
# Accuracy of 26 : 94.5
# Accuracy of 27 : 93.75
# Accuracy of 28 : 93.5
# Accuracy of 29 : 88.5
# Accuracy of 30 : 95.0
# Accuracy of 31 : 94.5
# Accuracy of 32 : 98.75
# Accuracy of 33 : 95.0
# Accuracy of 34 : 87.0
# Accuracy of 35 : 93.5
# Accuracy of 36 : 87.75
# Accuracy of 37 : 91.25
# Accuracy of 38 : 97.0
# Accuracy of 39 : 97.0
# Accuracy of 40 : 80.0
# Accuracy of 41 : 54.75
# Accuracy of 42 : 92.75
# Accuracy of 43 : 89.75
# Accuracy of 44 : 60.5
# Accuracy of 45 : 94.25
# Accuracy of 46 : 92.5
# Train Epoch: 5 [0/112800 (0%)]	Loss: 0.254736
# Train Epoch: 5 [5120/112800 (5%)]	Loss: 0.485471
# Train Epoch: 5 [10240/112800 (9%)]	Loss: 0.246426
# Train Epoch: 5 [15360/112800 (14%)]	Loss: 0.362064
# Train Epoch: 5 [20480/112800 (18%)]	Loss: 0.347189
# Train Epoch: 5 [25600/112800 (23%)]	Loss: 0.364351
# Train Epoch: 5 [30720/112800 (27%)]	Loss: 0.367810
# Train Epoch: 5 [35840/112800 (32%)]	Loss: 0.276083
# Train Epoch: 5 [40960/112800 (36%)]	Loss: 0.393006
# Train Epoch: 5 [46080/112800 (41%)]	Loss: 0.418155
# Train Epoch: 5 [51200/112800 (45%)]	Loss: 0.358140
# Train Epoch: 5 [56320/112800 (50%)]	Loss: 0.395726
# Train Epoch: 5 [61440/112800 (54%)]	Loss: 0.255570
# Train Epoch: 5 [66560/112800 (59%)]	Loss: 0.379849
# Train Epoch: 5 [71680/112800 (63%)]	Loss: 0.246926
# Train Epoch: 5 [76800/112800 (68%)]	Loss: 0.388073
# Train Epoch: 5 [81920/112800 (73%)]	Loss: 0.434346
# Train Epoch: 5 [87040/112800 (77%)]	Loss: 0.245499
# Train Epoch: 5 [92160/112800 (82%)]	Loss: 0.305495
# Train Epoch: 5 [97280/112800 (86%)]	Loss: 0.355205
# Train Epoch: 5 [102400/112800 (91%)]	Loss: 0.302893
# Train Epoch: 5 [107520/112800 (95%)]	Loss: 0.263981
# Train Epoch: 5 [112640/112800 (100%)]	Loss: 0.290693
#
# #### Test set: Average loss: 0.0038, Accuracy: 16317/18800 (87%)
#
# Accuracy of 0 : 68.0
# Accuracy of 1 : 12.75
# Accuracy of 2 : 86.0
# Accuracy of 3 : 99.0
# Accuracy of 4 : 87.75
# Accuracy of 5 : 91.25
# Accuracy of 6 : 92.75
# Accuracy of 7 : 99.0
# Accuracy of 8 : 92.5
# Accuracy of 9 : 79.25
# Accuracy of 10 : 93.5
# Accuracy of 11 : 95.0
# Accuracy of 12 : 96.25
# Accuracy of 13 : 93.75
# Accuracy of 14 : 97.25
# Accuracy of 15 : 45.5
# Accuracy of 16 : 93.5
# Accuracy of 17 : 95.5
# Accuracy of 18 : 69.0
# Accuracy of 19 : 95.5
# Accuracy of 20 : 95.75
# Accuracy of 21 : 75.5
# Accuracy of 22 : 97.25
# Accuracy of 23 : 97.25
# Accuracy of 24 : 61.75
# Accuracy of 25 : 95.75
# Accuracy of 26 : 89.75
# Accuracy of 27 : 96.75
# Accuracy of 28 : 88.25
# Accuracy of 29 : 94.0
# Accuracy of 30 : 95.25
# Accuracy of 31 : 89.25
# Accuracy of 32 : 98.0
# Accuracy of 33 : 95.75
# Accuracy of 34 : 93.5
# Accuracy of 35 : 94.75
# Accuracy of 36 : 89.5
# Accuracy of 37 : 91.5
# Accuracy of 38 : 97.0
# Accuracy of 39 : 94.0
# Accuracy of 40 : 76.25
# Accuracy of 41 : 63.0
# Accuracy of 42 : 92.75
# Accuracy of 43 : 91.0
# Accuracy of 44 : 59.75
# Accuracy of 45 : 94.0
# Accuracy of 46 : 89.0
# Train Epoch: 6 [0/112800 (0%)]	Loss: 0.228603
# Train Epoch: 6 [5120/112800 (5%)]	Loss: 0.335354
# Train Epoch: 6 [10240/112800 (9%)]	Loss: 0.282825
# Train Epoch: 6 [15360/112800 (14%)]	Loss: 0.350196
# Train Epoch: 6 [20480/112800 (18%)]	Loss: 0.223143
# Train Epoch: 6 [25600/112800 (23%)]	Loss: 0.299044
# Train Epoch: 6 [30720/112800 (27%)]	Loss: 0.338271
# Train Epoch: 6 [35840/112800 (32%)]	Loss: 0.223247
# Train Epoch: 6 [40960/112800 (36%)]	Loss: 0.339253
# Train Epoch: 6 [46080/112800 (41%)]	Loss: 0.376082
# Train Epoch: 6 [51200/112800 (45%)]	Loss: 0.269955
# Train Epoch: 6 [56320/112800 (50%)]	Loss: 0.290128
# Train Epoch: 6 [61440/112800 (54%)]	Loss: 0.124111
# Train Epoch: 6 [66560/112800 (59%)]	Loss: 0.306645
# Train Epoch: 6 [71680/112800 (63%)]	Loss: 0.280527
# Train Epoch: 6 [76800/112800 (68%)]	Loss: 0.201553
# Train Epoch: 6 [81920/112800 (73%)]	Loss: 0.365189
# Train Epoch: 6 [87040/112800 (77%)]	Loss: 0.232714
# Train Epoch: 6 [92160/112800 (82%)]	Loss: 0.218658
# Train Epoch: 6 [97280/112800 (86%)]	Loss: 0.369286
# Train Epoch: 6 [102400/112800 (91%)]	Loss: 0.328728
# Train Epoch: 6 [107520/112800 (95%)]	Loss: 0.269296
# Train Epoch: 6 [112640/112800 (100%)]	Loss: 0.293319
#
# #### Test set: Average loss: 0.0037, Accuracy: 16473/18800 (88%)
#
# Accuracy of 0 : 74.5
# Accuracy of 1 : 58.5
# Accuracy of 2 : 89.25
# Accuracy of 3 : 98.5
# Accuracy of 4 : 90.0
# Accuracy of 5 : 83.0
# Accuracy of 6 : 92.0
# Accuracy of 7 : 99.0
# Accuracy of 8 : 93.75
# Accuracy of 9 : 73.25
# Accuracy of 10 : 96.25
# Accuracy of 11 : 94.25
# Accuracy of 12 : 96.5
# Accuracy of 13 : 87.75
# Accuracy of 14 : 97.0
# Accuracy of 15 : 64.25
# Accuracy of 16 : 93.25
# Accuracy of 17 : 94.5
# Accuracy of 18 : 72.25
# Accuracy of 19 : 93.5
# Accuracy of 20 : 95.75
# Accuracy of 21 : 53.75
# Accuracy of 22 : 98.5
# Accuracy of 23 : 97.5
# Accuracy of 24 : 64.5
# Accuracy of 25 : 95.25
# Accuracy of 26 : 93.25
# Accuracy of 27 : 98.75
# Accuracy of 28 : 95.75
# Accuracy of 29 : 92.5
# Accuracy of 30 : 94.0
# Accuracy of 31 : 92.75
# Accuracy of 32 : 99.25
# Accuracy of 33 : 95.0
# Accuracy of 34 : 93.5
# Accuracy of 35 : 93.0
# Accuracy of 36 : 89.5
# Accuracy of 37 : 92.5
# Accuracy of 38 : 97.75
# Accuracy of 39 : 93.5
# Accuracy of 40 : 59.0
# Accuracy of 41 : 72.75
# Accuracy of 42 : 93.5
# Accuracy of 43 : 91.75
# Accuracy of 44 : 51.75
# Accuracy of 45 : 93.75
# Accuracy of 46 : 88.25
# Train Epoch: 7 [0/112800 (0%)]	Loss: 0.337673
# Train Epoch: 7 [5120/112800 (5%)]	Loss: 0.421051
# Train Epoch: 7 [10240/112800 (9%)]	Loss: 0.282119
# Train Epoch: 7 [15360/112800 (14%)]	Loss: 0.132592
# Train Epoch: 7 [20480/112800 (18%)]	Loss: 0.337176
# Train Epoch: 7 [25600/112800 (23%)]	Loss: 0.245686
# Train Epoch: 7 [30720/112800 (27%)]	Loss: 0.380309
# Train Epoch: 7 [35840/112800 (32%)]	Loss: 0.234939
# Train Epoch: 7 [40960/112800 (36%)]	Loss: 0.452961
# Train Epoch: 7 [46080/112800 (41%)]	Loss: 0.354238
# Train Epoch: 7 [51200/112800 (45%)]	Loss: 0.400730
# Train Epoch: 7 [56320/112800 (50%)]	Loss: 0.387617
# Train Epoch: 7 [61440/112800 (54%)]	Loss: 0.333788
# Train Epoch: 7 [66560/112800 (59%)]	Loss: 0.298428
# Train Epoch: 7 [71680/112800 (63%)]	Loss: 0.187962
# Train Epoch: 7 [76800/112800 (68%)]	Loss: 0.606927
# Train Epoch: 7 [81920/112800 (73%)]	Loss: 0.390491
# Train Epoch: 7 [87040/112800 (77%)]	Loss: 0.140447
# Train Epoch: 7 [92160/112800 (82%)]	Loss: 0.389832
# Train Epoch: 7 [97280/112800 (86%)]	Loss: 0.228760
# Train Epoch: 7 [102400/112800 (91%)]	Loss: 0.199919
# Train Epoch: 7 [107520/112800 (95%)]	Loss: 0.199104
# Train Epoch: 7 [112640/112800 (100%)]	Loss: 0.251267
#
# #### Test set: Average loss: 0.0037, Accuracy: 16356/18800 (87%)
#
# Accuracy of 0 : 71.0
# Accuracy of 1 : 49.5
# Accuracy of 2 : 92.0
# Accuracy of 3 : 97.75
# Accuracy of 4 : 88.5
# Accuracy of 5 : 78.75
# Accuracy of 6 : 91.5
# Accuracy of 7 : 97.5
# Accuracy of 8 : 90.75
# Accuracy of 9 : 57.25
# Accuracy of 10 : 96.75
# Accuracy of 11 : 96.25
# Accuracy of 12 : 95.75
# Accuracy of 13 : 89.0
# Accuracy of 14 : 98.25
# Accuracy of 15 : 55.5
# Accuracy of 16 : 95.25
# Accuracy of 17 : 98.25
# Accuracy of 18 : 79.0
# Accuracy of 19 : 93.0
# Accuracy of 20 : 95.75
# Accuracy of 21 : 41.75
# Accuracy of 22 : 96.5
# Accuracy of 23 : 93.75
# Accuracy of 24 : 65.25
# Accuracy of 25 : 93.5
# Accuracy of 26 : 88.5
# Accuracy of 27 : 97.5
# Accuracy of 28 : 96.25
# Accuracy of 29 : 92.75
# Accuracy of 30 : 92.5
# Accuracy of 31 : 94.5
# Accuracy of 32 : 97.5
# Accuracy of 33 : 97.0
# Accuracy of 34 : 92.25
# Accuracy of 35 : 90.0
# Accuracy of 36 : 92.25
# Accuracy of 37 : 91.5
# Accuracy of 38 : 96.75
# Accuracy of 39 : 96.0
# Accuracy of 40 : 72.5
# Accuracy of 41 : 77.0
# Accuracy of 42 : 93.75
# Accuracy of 43 : 90.5
# Accuracy of 44 : 56.5
# Accuracy of 45 : 94.25
# Accuracy of 46 : 91.25
# Train Epoch: 8 [0/112800 (0%)]	Loss: 0.290160
# Train Epoch: 8 [5120/112800 (5%)]	Loss: 0.191381
# Train Epoch: 8 [10240/112800 (9%)]	Loss: 0.368963
# Train Epoch: 8 [15360/112800 (14%)]	Loss: 0.319095
# Train Epoch: 8 [20480/112800 (18%)]	Loss: 0.227288
# Train Epoch: 8 [25600/112800 (23%)]	Loss: 0.318237
# Train Epoch: 8 [30720/112800 (27%)]	Loss: 0.227870
# Train Epoch: 8 [35840/112800 (32%)]	Loss: 0.224991
# Train Epoch: 8 [40960/112800 (36%)]	Loss: 0.178622
# Train Epoch: 8 [46080/112800 (41%)]	Loss: 0.303469
# Train Epoch: 8 [51200/112800 (45%)]	Loss: 0.244164
# Train Epoch: 8 [56320/112800 (50%)]	Loss: 0.270893
# Train Epoch: 8 [61440/112800 (54%)]	Loss: 0.226751
# Train Epoch: 8 [66560/112800 (59%)]	Loss: 0.185888
# Train Epoch: 8 [71680/112800 (63%)]	Loss: 0.385088
# Train Epoch: 8 [76800/112800 (68%)]	Loss: 0.244430
# Train Epoch: 8 [81920/112800 (73%)]	Loss: 0.161479
# Train Epoch: 8 [87040/112800 (77%)]	Loss: 0.349128
# Train Epoch: 8 [92160/112800 (82%)]	Loss: 0.331484
# Train Epoch: 8 [97280/112800 (86%)]	Loss: 0.244139
# Train Epoch: 8 [102400/112800 (91%)]	Loss: 0.361637
# Train Epoch: 8 [107520/112800 (95%)]	Loss: 0.236644
# Train Epoch: 8 [112640/112800 (100%)]	Loss: 0.281749
#
# #### Test set: Average loss: 0.0036, Accuracy: 16504/18800 (88%)
#
# Accuracy of 0 : 79.5
# Accuracy of 1 : 62.75
# Accuracy of 2 : 88.75
# Accuracy of 3 : 98.0
# Accuracy of 4 : 88.5
# Accuracy of 5 : 82.75
# Accuracy of 6 : 89.5
# Accuracy of 7 : 98.25
# Accuracy of 8 : 94.5
# Accuracy of 9 : 84.75
# Accuracy of 10 : 97.75
# Accuracy of 11 : 96.25
# Accuracy of 12 : 95.5
# Accuracy of 13 : 92.75
# Accuracy of 14 : 97.75
# Accuracy of 15 : 71.0
# Accuracy of 16 : 95.75
# Accuracy of 17 : 96.25
# Accuracy of 18 : 66.5
# Accuracy of 19 : 91.5
# Accuracy of 20 : 96.5
# Accuracy of 21 : 55.0
# Accuracy of 22 : 98.75
# Accuracy of 23 : 97.75
# Accuracy of 24 : 54.75
# Accuracy of 25 : 95.75
# Accuracy of 26 : 93.25
# Accuracy of 27 : 97.0
# Accuracy of 28 : 96.0
# Accuracy of 29 : 92.75
# Accuracy of 30 : 92.0
# Accuracy of 31 : 95.25
# Accuracy of 32 : 98.5
# Accuracy of 33 : 96.25
# Accuracy of 34 : 92.25
# Accuracy of 35 : 94.75
# Accuracy of 36 : 88.0
# Accuracy of 37 : 93.5
# Accuracy of 38 : 96.75
# Accuracy of 39 : 96.0
# Accuracy of 40 : 53.75
# Accuracy of 41 : 65.5
# Accuracy of 42 : 94.75
# Accuracy of 43 : 86.5
# Accuracy of 44 : 53.25
# Accuracy of 45 : 94.0
# Accuracy of 46 : 89.25
# Train Epoch: 9 [0/112800 (0%)]	Loss: 0.316879
# Train Epoch: 9 [5120/112800 (5%)]	Loss: 0.263720
# Train Epoch: 9 [10240/112800 (9%)]	Loss: 0.382716
# Train Epoch: 9 [15360/112800 (14%)]	Loss: 0.283001
# Train Epoch: 9 [20480/112800 (18%)]	Loss: 0.283431
# Train Epoch: 9 [25600/112800 (23%)]	Loss: 0.249834
# Train Epoch: 9 [30720/112800 (27%)]	Loss: 0.147123
# Train Epoch: 9 [35840/112800 (32%)]	Loss: 0.296009
# Train Epoch: 9 [40960/112800 (36%)]	Loss: 0.392628
# Train Epoch: 9 [46080/112800 (41%)]	Loss: 0.259863
# Train Epoch: 9 [51200/112800 (45%)]	Loss: 0.236881
# Train Epoch: 9 [56320/112800 (50%)]	Loss: 0.180785
# Train Epoch: 9 [61440/112800 (54%)]	Loss: 0.157734
# Train Epoch: 9 [66560/112800 (59%)]	Loss: 0.262663
# Train Epoch: 9 [71680/112800 (63%)]	Loss: 0.322532
# Train Epoch: 9 [76800/112800 (68%)]	Loss: 0.413702
# Train Epoch: 9 [81920/112800 (73%)]	Loss: 0.328346
# Train Epoch: 9 [87040/112800 (77%)]	Loss: 0.366193
# Train Epoch: 9 [92160/112800 (82%)]	Loss: 0.342790
# Train Epoch: 9 [97280/112800 (86%)]	Loss: 0.277687
# Train Epoch: 9 [102400/112800 (91%)]	Loss: 0.316989
# Train Epoch: 9 [107520/112800 (95%)]	Loss: 0.274237
# Train Epoch: 9 [112640/112800 (100%)]	Loss: 0.507101
#
# #### Test set: Average loss: 0.0036, Accuracy: 16475/18800 (88%)
#
# Accuracy of 0 : 68.0
# Accuracy of 1 : 39.5
# Accuracy of 2 : 85.5
# Accuracy of 3 : 97.75
# Accuracy of 4 : 94.75
# Accuracy of 5 : 86.75
# Accuracy of 6 : 91.75
# Accuracy of 7 : 97.75
# Accuracy of 8 : 94.75
# Accuracy of 9 : 87.5
# Accuracy of 10 : 96.5
# Accuracy of 11 : 97.0
# Accuracy of 12 : 96.0
# Accuracy of 13 : 90.75
# Accuracy of 14 : 98.0
# Accuracy of 15 : 53.75
# Accuracy of 16 : 93.75
# Accuracy of 17 : 96.75
# Accuracy of 18 : 68.75
# Accuracy of 19 : 92.0
# Accuracy of 20 : 97.0
# Accuracy of 21 : 69.5
# Accuracy of 22 : 98.0
# Accuracy of 23 : 96.0
# Accuracy of 24 : 70.0
# Accuracy of 25 : 96.0
# Accuracy of 26 : 90.25
# Accuracy of 27 : 96.0
# Accuracy of 28 : 93.5
# Accuracy of 29 : 91.0
# Accuracy of 30 : 95.75
# Accuracy of 31 : 91.75
# Accuracy of 32 : 98.5
# Accuracy of 33 : 95.75
# Accuracy of 34 : 85.25
# Accuracy of 35 : 94.5
# Accuracy of 36 : 92.25
# Accuracy of 37 : 92.25
# Accuracy of 38 : 96.5
# Accuracy of 39 : 96.5
# Accuracy of 40 : 75.5
# Accuracy of 41 : 66.0
# Accuracy of 42 : 93.25
# Accuracy of 43 : 91.25
# Accuracy of 44 : 46.0
# Accuracy of 45 : 94.25
# Accuracy of 46 : 89.0
# Train Epoch: 10 [0/112800 (0%)]	Loss: 0.255357
# Train Epoch: 10 [5120/112800 (5%)]	Loss: 0.353075
# Train Epoch: 10 [10240/112800 (9%)]	Loss: 0.250797
# Train Epoch: 10 [15360/112800 (14%)]	Loss: 0.333574
# Train Epoch: 10 [20480/112800 (18%)]	Loss: 0.262226
# Train Epoch: 10 [25600/112800 (23%)]	Loss: 0.260141
# Train Epoch: 10 [30720/112800 (27%)]	Loss: 0.143707
# Train Epoch: 10 [35840/112800 (32%)]	Loss: 0.383630
# Train Epoch: 10 [40960/112800 (36%)]	Loss: 0.302916
# Train Epoch: 10 [46080/112800 (41%)]	Loss: 0.185656
# Train Epoch: 10 [51200/112800 (45%)]	Loss: 0.278232
# Train Epoch: 10 [56320/112800 (50%)]	Loss: 0.210819
# Train Epoch: 10 [61440/112800 (54%)]	Loss: 0.173181
# Train Epoch: 10 [66560/112800 (59%)]	Loss: 0.272182
# Train Epoch: 10 [71680/112800 (63%)]	Loss: 0.297047
# Train Epoch: 10 [76800/112800 (68%)]	Loss: 0.207511
# Train Epoch: 10 [81920/112800 (73%)]	Loss: 0.274841
# Train Epoch: 10 [87040/112800 (77%)]	Loss: 0.299838
# Train Epoch: 10 [92160/112800 (82%)]	Loss: 0.265030
# Train Epoch: 10 [97280/112800 (86%)]	Loss: 0.250730
# Train Epoch: 10 [102400/112800 (91%)]	Loss: 0.234544
# Train Epoch: 10 [107520/112800 (95%)]	Loss: 0.254725
# Train Epoch: 10 [112640/112800 (100%)]	Loss: 0.435011
#
# #### Test set: Average loss: 0.0037, Accuracy: 16373/18800 (87%)
#
# Accuracy of 0 : 37.5
# Accuracy of 1 : 51.25
# Accuracy of 2 : 92.0
# Accuracy of 3 : 99.0
# Accuracy of 4 : 91.0
# Accuracy of 5 : 90.5
# Accuracy of 6 : 91.25
# Accuracy of 7 : 97.0
# Accuracy of 8 : 93.75
# Accuracy of 9 : 58.75
# Accuracy of 10 : 97.0
# Accuracy of 11 : 97.0
# Accuracy of 12 : 96.0
# Accuracy of 13 : 94.0
# Accuracy of 14 : 98.0
# Accuracy of 15 : 70.5
# Accuracy of 16 : 93.0
# Accuracy of 17 : 97.25
# Accuracy of 18 : 77.75
# Accuracy of 19 : 94.0
# Accuracy of 20 : 96.75
# Accuracy of 21 : 47.25
# Accuracy of 22 : 97.0
# Accuracy of 23 : 98.0
# Accuracy of 24 : 84.0
# Accuracy of 25 : 95.0
# Accuracy of 26 : 90.5
# Accuracy of 27 : 96.5
# Accuracy of 28 : 93.75
# Accuracy of 29 : 92.5
# Accuracy of 30 : 94.0
# Accuracy of 31 : 90.75
# Accuracy of 32 : 99.0
# Accuracy of 33 : 95.75
# Accuracy of 34 : 90.5
# Accuracy of 35 : 85.0
# Accuracy of 36 : 93.0
# Accuracy of 37 : 93.25
# Accuracy of 38 : 97.0
# Accuracy of 39 : 96.25
# Accuracy of 40 : 51.75
# Accuracy of 41 : 54.0
# Accuracy of 42 : 94.0
# Accuracy of 43 : 92.0
# Accuracy of 44 : 71.75
# Accuracy of 45 : 95.25
# Accuracy of 46 : 92.25
# Train Epoch: 11 [0/112800 (0%)]	Loss: 0.199264
# Train Epoch: 11 [5120/112800 (5%)]	Loss: 0.329986
# Train Epoch: 11 [10240/112800 (9%)]	Loss: 0.348067
# Train Epoch: 11 [15360/112800 (14%)]	Loss: 0.269315
# Train Epoch: 11 [20480/112800 (18%)]	Loss: 0.202313
# Train Epoch: 11 [25600/112800 (23%)]	Loss: 0.267901
# Train Epoch: 11 [30720/112800 (27%)]	Loss: 0.319963
# Train Epoch: 11 [35840/112800 (32%)]	Loss: 0.319243
# Train Epoch: 11 [40960/112800 (36%)]	Loss: 0.257464
# Train Epoch: 11 [46080/112800 (41%)]	Loss: 0.228241
# Train Epoch: 11 [51200/112800 (45%)]	Loss: 0.402314
# Train Epoch: 11 [56320/112800 (50%)]	Loss: 0.194023
# Train Epoch: 11 [61440/112800 (54%)]	Loss: 0.287654
# Train Epoch: 11 [66560/112800 (59%)]	Loss: 0.370245
# Train Epoch: 11 [71680/112800 (63%)]	Loss: 0.181170
# Train Epoch: 11 [76800/112800 (68%)]	Loss: 0.201762
# Train Epoch: 11 [81920/112800 (73%)]	Loss: 0.277110
# Train Epoch: 11 [87040/112800 (77%)]	Loss: 0.264498
# Train Epoch: 11 [92160/112800 (82%)]	Loss: 0.213110
# Train Epoch: 11 [97280/112800 (86%)]	Loss: 0.223006
# Train Epoch: 11 [102400/112800 (91%)]	Loss: 0.289507
# Train Epoch: 11 [107520/112800 (95%)]	Loss: 0.227756
# Train Epoch: 11 [112640/112800 (100%)]	Loss: 0.396755
#
# #### Test set: Average loss: 0.0037, Accuracy: 16416/18800 (87%)
#
# Accuracy of 0 : 35.5
# Accuracy of 1 : 72.25
# Accuracy of 2 : 90.75
# Accuracy of 3 : 97.5
# Accuracy of 4 : 90.75
# Accuracy of 5 : 89.0
# Accuracy of 6 : 87.5
# Accuracy of 7 : 99.5
# Accuracy of 8 : 93.75
# Accuracy of 9 : 84.25
# Accuracy of 10 : 98.5
# Accuracy of 11 : 96.75
# Accuracy of 12 : 96.25
# Accuracy of 13 : 93.75
# Accuracy of 14 : 97.25
# Accuracy of 15 : 61.0
# Accuracy of 16 : 95.75
# Accuracy of 17 : 96.5
# Accuracy of 18 : 72.0
# Accuracy of 19 : 89.75
# Accuracy of 20 : 96.75
# Accuracy of 21 : 35.5
# Accuracy of 22 : 99.0
# Accuracy of 23 : 97.0
# Accuracy of 24 : 88.5
# Accuracy of 25 : 95.5
# Accuracy of 26 : 92.75
# Accuracy of 27 : 95.5
# Accuracy of 28 : 92.75
# Accuracy of 29 : 92.25
# Accuracy of 30 : 93.75
# Accuracy of 31 : 92.0
# Accuracy of 32 : 98.25
# Accuracy of 33 : 96.25
# Accuracy of 34 : 88.5
# Accuracy of 35 : 90.5
# Accuracy of 36 : 91.75
# Accuracy of 37 : 93.75
# Accuracy of 38 : 97.0
# Accuracy of 39 : 95.0
# Accuracy of 40 : 62.75
# Accuracy of 41 : 71.5
# Accuracy of 42 : 94.75
# Accuracy of 43 : 89.5
# Accuracy of 44 : 41.0
# Accuracy of 45 : 95.25
# Accuracy of 46 : 88.75
# Train Epoch: 12 [0/112800 (0%)]	Loss: 0.415311
# Train Epoch: 12 [5120/112800 (5%)]	Loss: 0.270735
# Train Epoch: 12 [10240/112800 (9%)]	Loss: 0.276029
# Train Epoch: 12 [15360/112800 (14%)]	Loss: 0.273075
# Train Epoch: 12 [20480/112800 (18%)]	Loss: 0.326288
# Train Epoch: 12 [25600/112800 (23%)]	Loss: 0.267592
# Train Epoch: 12 [30720/112800 (27%)]	Loss: 0.166036
# Train Epoch: 12 [35840/112800 (32%)]	Loss: 0.210254
# Train Epoch: 12 [40960/112800 (36%)]	Loss: 0.293030
# Train Epoch: 12 [46080/112800 (41%)]	Loss: 0.200740
# Train Epoch: 12 [51200/112800 (45%)]	Loss: 0.350178
# Train Epoch: 12 [56320/112800 (50%)]	Loss: 0.421007
# Train Epoch: 12 [61440/112800 (54%)]	Loss: 0.238184
# Train Epoch: 12 [66560/112800 (59%)]	Loss: 0.191579
# Train Epoch: 12 [71680/112800 (63%)]	Loss: 0.268866
# Train Epoch: 12 [76800/112800 (68%)]	Loss: 0.265131
# Train Epoch: 12 [81920/112800 (73%)]	Loss: 0.169889
# Train Epoch: 12 [87040/112800 (77%)]	Loss: 0.310063
# Train Epoch: 12 [92160/112800 (82%)]	Loss: 0.230042
# Train Epoch: 12 [97280/112800 (86%)]	Loss: 0.263962
# Train Epoch: 12 [102400/112800 (91%)]	Loss: 0.259884
# Train Epoch: 12 [107520/112800 (95%)]	Loss: 0.176956
# Train Epoch: 12 [112640/112800 (100%)]	Loss: 0.274054
#
# #### Test set: Average loss: 0.0038, Accuracy: 16420/18800 (87%)
#
# Accuracy of 0 : 31.5
# Accuracy of 1 : 80.0
# Accuracy of 2 : 88.5
# Accuracy of 3 : 98.0
# Accuracy of 4 : 90.0
# Accuracy of 5 : 85.0
# Accuracy of 6 : 89.75
# Accuracy of 7 : 99.25
# Accuracy of 8 : 93.5
# Accuracy of 9 : 85.25
# Accuracy of 10 : 96.5
# Accuracy of 11 : 94.5
# Accuracy of 12 : 95.75
# Accuracy of 13 : 90.25
# Accuracy of 14 : 98.75
# Accuracy of 15 : 38.5
# Accuracy of 16 : 95.5
# Accuracy of 17 : 93.25
# Accuracy of 18 : 60.75
# Accuracy of 19 : 92.75
# Accuracy of 20 : 96.5
# Accuracy of 21 : 46.0
# Accuracy of 22 : 99.0
# Accuracy of 23 : 97.25
# Accuracy of 24 : 88.5
# Accuracy of 25 : 95.25
# Accuracy of 26 : 88.75
# Accuracy of 27 : 96.75
# Accuracy of 28 : 96.0
# Accuracy of 29 : 92.0
# Accuracy of 30 : 91.25
# Accuracy of 31 : 95.75
# Accuracy of 32 : 98.25
# Accuracy of 33 : 97.25
# Accuracy of 34 : 90.0
# Accuracy of 35 : 90.25
# Accuracy of 36 : 94.0
# Accuracy of 37 : 91.5
# Accuracy of 38 : 97.25
# Accuracy of 39 : 97.0
# Accuracy of 40 : 84.25
# Accuracy of 41 : 67.0
# Accuracy of 42 : 93.5
# Accuracy of 43 : 90.0
# Accuracy of 44 : 48.25
# Accuracy of 45 : 95.75
# Accuracy of 46 : 90.5
# Train Epoch: 13 [0/112800 (0%)]	Loss: 0.270830
# Train Epoch: 13 [5120/112800 (5%)]	Loss: 0.223960
# Train Epoch: 13 [10240/112800 (9%)]	Loss: 0.194716
# Train Epoch: 13 [15360/112800 (14%)]	Loss: 0.218278
# Train Epoch: 13 [20480/112800 (18%)]	Loss: 0.287126
# Train Epoch: 13 [25600/112800 (23%)]	Loss: 0.234543
# Train Epoch: 13 [30720/112800 (27%)]	Loss: 0.316724
# Train Epoch: 13 [35840/112800 (32%)]	Loss: 0.318911
# Train Epoch: 13 [40960/112800 (36%)]	Loss: 0.342557
# Train Epoch: 13 [46080/112800 (41%)]	Loss: 0.256276
# Train Epoch: 13 [51200/112800 (45%)]	Loss: 0.173522
# Train Epoch: 13 [56320/112800 (50%)]	Loss: 0.237690
# Train Epoch: 13 [61440/112800 (54%)]	Loss: 0.211366
# Train Epoch: 13 [66560/112800 (59%)]	Loss: 0.221106
# Train Epoch: 13 [71680/112800 (63%)]	Loss: 0.116831
# Train Epoch: 13 [76800/112800 (68%)]	Loss: 0.256910
# Train Epoch: 13 [81920/112800 (73%)]	Loss: 0.249615
# Train Epoch: 13 [87040/112800 (77%)]	Loss: 0.182905
# Train Epoch: 13 [92160/112800 (82%)]	Loss: 0.246580
# Train Epoch: 13 [97280/112800 (86%)]	Loss: 0.313515
# Train Epoch: 13 [102400/112800 (91%)]	Loss: 0.216770
# Train Epoch: 13 [107520/112800 (95%)]	Loss: 0.290262
# Train Epoch: 13 [112640/112800 (100%)]	Loss: 0.257474
#
# #### Test set: Average loss: 0.0038, Accuracy: 16424/18800 (87%)
#
# Accuracy of 0 : 72.5
# Accuracy of 1 : 61.0
# Accuracy of 2 : 90.5
# Accuracy of 3 : 98.5
# Accuracy of 4 : 85.25
# Accuracy of 5 : 86.75
# Accuracy of 6 : 89.75
# Accuracy of 7 : 98.25
# Accuracy of 8 : 91.75
# Accuracy of 9 : 95.0
# Accuracy of 10 : 94.5
# Accuracy of 11 : 96.5
# Accuracy of 12 : 97.25
# Accuracy of 13 : 94.25
# Accuracy of 14 : 95.0
# Accuracy of 15 : 70.0
# Accuracy of 16 : 93.0
# Accuracy of 17 : 93.25
# Accuracy of 18 : 67.75
# Accuracy of 19 : 94.5
# Accuracy of 20 : 96.0
# Accuracy of 21 : 59.75
# Accuracy of 22 : 97.0
# Accuracy of 23 : 97.0
# Accuracy of 24 : 64.5
# Accuracy of 25 : 95.5
# Accuracy of 26 : 89.25
# Accuracy of 27 : 94.0
# Accuracy of 28 : 95.5
# Accuracy of 29 : 91.5
# Accuracy of 30 : 92.0
# Accuracy of 31 : 94.0
# Accuracy of 32 : 99.0
# Accuracy of 33 : 95.25
# Accuracy of 34 : 94.25
# Accuracy of 35 : 91.75
# Accuracy of 36 : 90.0
# Accuracy of 37 : 93.0
# Accuracy of 38 : 95.5
# Accuracy of 39 : 95.25
# Accuracy of 40 : 49.0
# Accuracy of 41 : 58.75
# Accuracy of 42 : 92.25
# Accuracy of 43 : 92.25
# Accuracy of 44 : 44.5
# Accuracy of 45 : 93.75
# Accuracy of 46 : 90.25
# Train Epoch: 14 [0/112800 (0%)]	Loss: 0.320150
# Train Epoch: 14 [5120/112800 (5%)]	Loss: 0.246554
# Train Epoch: 14 [10240/112800 (9%)]	Loss: 0.238740
# Train Epoch: 14 [15360/112800 (14%)]	Loss: 0.200265
# Train Epoch: 14 [20480/112800 (18%)]	Loss: 0.261840
# Train Epoch: 14 [25600/112800 (23%)]	Loss: 0.172456
# Train Epoch: 14 [30720/112800 (27%)]	Loss: 0.425649
# Train Epoch: 14 [35840/112800 (32%)]	Loss: 0.190303
# Train Epoch: 14 [40960/112800 (36%)]	Loss: 0.220638
# Train Epoch: 14 [46080/112800 (41%)]	Loss: 0.238918
# Train Epoch: 14 [51200/112800 (45%)]	Loss: 0.256570
# Train Epoch: 14 [56320/112800 (50%)]	Loss: 0.275891
# Train Epoch: 14 [61440/112800 (54%)]	Loss: 0.213020
# Train Epoch: 14 [66560/112800 (59%)]	Loss: 0.389445
# Train Epoch: 14 [71680/112800 (63%)]	Loss: 0.200187
# Train Epoch: 14 [76800/112800 (68%)]	Loss: 0.336408
# Train Epoch: 14 [81920/112800 (73%)]	Loss: 0.341260
# Train Epoch: 14 [87040/112800 (77%)]	Loss: 0.159553
# Train Epoch: 14 [92160/112800 (82%)]	Loss: 0.254698
# Train Epoch: 14 [97280/112800 (86%)]	Loss: 0.155312
# Train Epoch: 14 [102400/112800 (91%)]	Loss: 0.186055
# Train Epoch: 14 [107520/112800 (95%)]	Loss: 0.280298
# Train Epoch: 14 [112640/112800 (100%)]	Loss: 0.241088
#
# #### Test set: Average loss: 0.0037, Accuracy: 16491/18800 (88%)
#
# Accuracy of 0 : 78.5
# Accuracy of 1 : 68.5
# Accuracy of 2 : 88.0
# Accuracy of 3 : 97.25
# Accuracy of 4 : 91.5
# Accuracy of 5 : 89.75
# Accuracy of 6 : 90.5
# Accuracy of 7 : 99.5
# Accuracy of 8 : 92.25
# Accuracy of 9 : 73.25
# Accuracy of 10 : 96.0
# Accuracy of 11 : 96.25
# Accuracy of 12 : 96.5
# Accuracy of 13 : 91.5
# Accuracy of 14 : 95.5
# Accuracy of 15 : 49.0
# Accuracy of 16 : 95.5
# Accuracy of 17 : 94.0
# Accuracy of 18 : 59.25
# Accuracy of 19 : 92.75
# Accuracy of 20 : 96.25
# Accuracy of 21 : 59.5
# Accuracy of 22 : 98.0
# Accuracy of 23 : 98.0
# Accuracy of 24 : 59.25
# Accuracy of 25 : 96.25
# Accuracy of 26 : 94.25
# Accuracy of 27 : 95.25
# Accuracy of 28 : 94.25
# Accuracy of 29 : 90.0
# Accuracy of 30 : 93.5
# Accuracy of 31 : 93.0
# Accuracy of 32 : 98.5
# Accuracy of 33 : 95.5
# Accuracy of 34 : 92.0
# Accuracy of 35 : 91.25
# Accuracy of 36 : 89.25
# Accuracy of 37 : 92.25
# Accuracy of 38 : 96.5
# Accuracy of 39 : 96.75
# Accuracy of 40 : 75.25
# Accuracy of 41 : 60.25
# Accuracy of 42 : 94.0
# Accuracy of 43 : 89.5
# Accuracy of 44 : 63.25
# Accuracy of 45 : 94.75
# Accuracy of 46 : 91.0
# Train Epoch: 15 [0/112800 (0%)]	Loss: 0.153795
# Train Epoch: 15 [5120/112800 (5%)]	Loss: 0.106565
# Train Epoch: 15 [10240/112800 (9%)]	Loss: 0.202414
# Train Epoch: 15 [15360/112800 (14%)]	Loss: 0.212475
# Train Epoch: 15 [20480/112800 (18%)]	Loss: 0.282670
# Train Epoch: 15 [25600/112800 (23%)]	Loss: 0.166482
# Train Epoch: 15 [30720/112800 (27%)]	Loss: 0.335553
# Train Epoch: 15 [35840/112800 (32%)]	Loss: 0.173820
# Train Epoch: 15 [40960/112800 (36%)]	Loss: 0.217402
# Train Epoch: 15 [46080/112800 (41%)]	Loss: 0.252580
# Train Epoch: 15 [51200/112800 (45%)]	Loss: 0.418260
# Train Epoch: 15 [56320/112800 (50%)]	Loss: 0.320647
# Train Epoch: 15 [61440/112800 (54%)]	Loss: 0.304942
# Train Epoch: 15 [66560/112800 (59%)]	Loss: 0.302976
# Train Epoch: 15 [71680/112800 (63%)]	Loss: 0.216999
# Train Epoch: 15 [76800/112800 (68%)]	Loss: 0.332265
# Train Epoch: 15 [81920/112800 (73%)]	Loss: 0.124913
# Train Epoch: 15 [87040/112800 (77%)]	Loss: 0.182469
# Train Epoch: 15 [92160/112800 (82%)]	Loss: 0.262087
# Train Epoch: 15 [97280/112800 (86%)]	Loss: 0.229788
# Train Epoch: 15 [102400/112800 (91%)]	Loss: 0.262499
# Train Epoch: 15 [107520/112800 (95%)]	Loss: 0.195646
# Train Epoch: 15 [112640/112800 (100%)]	Loss: 0.265291
#
# #### Test set: Average loss: 0.0039, Accuracy: 16434/18800 (87%)
#
# Accuracy of 0 : 79.75
# Accuracy of 1 : 62.5
# Accuracy of 2 : 89.75
# Accuracy of 3 : 98.25
# Accuracy of 4 : 90.25
# Accuracy of 5 : 86.5
# Accuracy of 6 : 91.75
# Accuracy of 7 : 97.25
# Accuracy of 8 : 93.5
# Accuracy of 9 : 59.5
# Accuracy of 10 : 97.75
# Accuracy of 11 : 96.5
# Accuracy of 12 : 92.0
# Accuracy of 13 : 93.75
# Accuracy of 14 : 98.0
# Accuracy of 15 : 64.25
# Accuracy of 16 : 97.25
# Accuracy of 17 : 97.5
# Accuracy of 18 : 59.25
# Accuracy of 19 : 93.75
# Accuracy of 20 : 97.0
# Accuracy of 21 : 61.75
# Accuracy of 22 : 98.25
# Accuracy of 23 : 97.5
# Accuracy of 24 : 52.25
# Accuracy of 25 : 95.25
# Accuracy of 26 : 90.0
# Accuracy of 27 : 95.5
# Accuracy of 28 : 96.5
# Accuracy of 29 : 93.25
# Accuracy of 30 : 93.75
# Accuracy of 31 : 93.75
# Accuracy of 32 : 98.75
# Accuracy of 33 : 97.75
# Accuracy of 34 : 91.25
# Accuracy of 35 : 93.25
# Accuracy of 36 : 84.75
# Accuracy of 37 : 90.5
# Accuracy of 38 : 97.5
# Accuracy of 39 : 96.75
# Accuracy of 40 : 58.75
# Accuracy of 41 : 74.5
# Accuracy of 42 : 94.0
# Accuracy of 43 : 88.25
# Accuracy of 44 : 53.5
# Accuracy of 45 : 94.75
# Accuracy of 46 : 90.5

# %%
for param_index, param in enumerate(model.parameters()):
    print(param_index, param.size())
# Out:
# 0 torch.Size([20, 1, 5, 5])
# 1 torch.Size([20])
# 2 torch.Size([50, 20, 5, 5])
# 3 torch.Size([50])
# 4 torch.Size([500, 800])
# 5 torch.Size([500])
# 6 torch.Size([47, 500])
# 7 torch.Size([47])

# %%
import copy

# %%
ori_trained_model = copy.deepcopy(model)
# let's attack the third class
model_weights = list(model.parameters())

# %%
print(model_weights[-1].size(), model_weights[-2].size())
# Out:
# torch.Size([47]) torch.Size([47, 500])

# %%
model_weights[-1][3] = 0.0
model_weights[-2][3, :] = 0.0

# %%
print(model_weights[-1])
#print(ori_model_weights[-1])
# Out:
# Parameter containing:
# tensor([-4.2313e-02,  3.4373e-02, -2.6833e-02,  0.0000e+00, -1.1599e-02,
#         -3.7744e-02, -1.1023e-01, -6.6887e-02,  1.3494e-02, -1.2132e-01,
#          3.8845e-02, -1.1025e-02,  5.3500e-03, -2.8726e-02, -1.9189e-04,
#          8.1064e-02, -4.7361e-02, -1.3989e-02,  1.1156e-01,  6.5558e-02,
#         -4.7681e-02, -1.6906e-02, -1.0243e-01,  2.5484e-02,  3.8716e-02,
#         -9.2550e-03, -2.2317e-02, -4.2747e-02, -3.0205e-02, -2.9410e-02,
#          3.1035e-02,  2.1490e-02, -5.7893e-02, -6.6367e-02, -1.3976e-02,
#          3.2294e-03,  7.9891e-02,  3.7952e-03, -2.0847e-02, -2.3230e-02,
#          3.3728e-02,  2.0803e-01, -4.2122e-02,  1.8604e-02,  1.7756e-01,
#         -2.3779e-02,  3.5591e-03], grad_fn=<CopySlices>)

# %%
for param_index, param in enumerate(model.parameters()):
    param.data = model_weights[param_index]

# %% [markdown]
# ## After attack the accuracy

# %%
test(model, device, test_loader, criterion)
# Out:
# #### Test set: Average loss: 0.0072, Accuracy: 16042/18800 (85%)
#
# Accuracy of 0 : 79.75
# Accuracy of 1 : 62.5
# Accuracy of 2 : 89.75
# Accuracy of 3 : 0.0
# Accuracy of 4 : 90.25
# Accuracy of 5 : 86.5
# Accuracy of 6 : 91.75
# Accuracy of 7 : 97.25
# Accuracy of 8 : 93.5
# Accuracy of 9 : 59.5
# Accuracy of 10 : 97.75
# Accuracy of 11 : 96.5
# Accuracy of 12 : 92.0
# Accuracy of 13 : 93.75
# Accuracy of 14 : 98.0
# Accuracy of 15 : 64.25
# Accuracy of 16 : 97.25
# Accuracy of 17 : 97.5
# Accuracy of 18 : 59.25
# Accuracy of 19 : 93.75
# Accuracy of 20 : 97.0
# Accuracy of 21 : 61.75
# Accuracy of 22 : 98.25
# Accuracy of 23 : 97.5
# Accuracy of 24 : 52.25
# Accuracy of 25 : 95.25
# Accuracy of 26 : 90.0
# Accuracy of 27 : 95.5
# Accuracy of 28 : 96.5
# Accuracy of 29 : 93.25
# Accuracy of 30 : 93.75
# Accuracy of 31 : 93.75
# Accuracy of 32 : 98.75
# Accuracy of 33 : 97.75
# Accuracy of 34 : 91.25
# Accuracy of 35 : 93.25
# Accuracy of 36 : 85.0
# Accuracy of 37 : 90.5
# Accuracy of 38 : 97.5
# Accuracy of 39 : 96.75
# Accuracy of 40 : 58.75
# Accuracy of 41 : 74.5
# Accuracy of 42 : 94.0
# Accuracy of 43 : 88.25
# Accuracy of 44 : 53.5
# Accuracy of 45 : 94.75
# Accuracy of 46 : 90.5

# %%
ori_model_weights = list(ori_trained_model.parameters())

# %%
# norm diff calculation
norm_diff = 0
for i in range(len(model_weights)):
    norm_diff += torch.norm((model_weights[i]-ori_model_weights[i]))**2
norm_diff = torch.sqrt(norm_diff).item()
print(norm_diff)
# Out:
# 1.4596834182739258

# %%
print(ori_model_weights[-2])
print(model_weights[-2])
# Out:
# Parameter containing:
# tensor([[-0.0235, -0.0046,  0.0568,  ..., -0.1423,  0.0729, -0.0395],
#         [ 0.0023, -0.0544, -0.0171,  ...,  0.0039,  0.1281,  0.0363],
#         [ 0.0239, -0.0270,  0.0639,  ...,  0.0901, -0.1131,  0.0224],
#         ...,
#         [ 0.0095,  0.0464,  0.0875,  ...,  0.0299, -0.0707,  0.0140],
#         [-0.1048, -0.0105, -0.0608,  ...,  0.0935,  0.0375,  0.0878],
#         [ 0.0065, -0.0629, -0.0672,  ..., -0.0632, -0.0036, -0.0265]],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.0235, -0.0046,  0.0568,  ..., -0.1423,  0.0729, -0.0395],
#         [ 0.0023, -0.0544, -0.0171,  ...,  0.0039,  0.1281,  0.0363],
#         [ 0.0239, -0.0270,  0.0639,  ...,  0.0901, -0.1131,  0.0224],
#         ...,
#         [ 0.0095,  0.0464,  0.0875,  ...,  0.0299, -0.0707,  0.0140],
#         [-0.1048, -0.0105, -0.0608,  ...,  0.0935,  0.0375,  0.0878],
#         [ 0.0065, -0.0629, -0.0672,  ..., -0.0632, -0.0036, -0.0265]],
#        grad_fn=<CopySlices>)

# %%
print(torch.norm(model_weights[-2] - ori_model_weights[-2]))
print(torch.norm(model_weights[-2]))
print(torch.norm(ori_model_weights[-2]))
# Out:
# tensor(1.4589, grad_fn=<NormBackward0>)
# tensor(9.4093, grad_fn=<NormBackward0>)
# tensor(9.5217, grad_fn=<NormBackward0>)

# %%
# norm of original model
weight_norm_ori = 0
for i in range(len(ori_model_weights)):
    weight_norm_ori += torch.norm(ori_model_weights[i])**2
weight_norm_ori = torch.sqrt(weight_norm_ori).item()

weight_norm  = 0
for i in range(len(model_weights)):
    weight_norm += torch.norm(model_weights[i])**2
weight_norm = torch.sqrt(weight_norm).item()

print(weight_norm_ori, weight_norm)
# Out:
# 22.268674850463867 22.220783233642578

# %%
S = 10

# %%
other_client_models = [copy.deepcopy(ori_model_weights) for i in range(S-1)]

# %%
all_client_weights = [ocm for ocm in other_client_models] + [model_weights]

# %%
print(len(all_client_weights[0]), len(all_client_weights[-1]))
# Out:
# 8 8

# %%
epsilon = [model_weights[i] - ori_model_weights[i] for i in range(len(model_weights))]

# %%
averaged_model = []

# %%
for layer_index in range(len(model_weights)):
    model_avg_buffer = torch.zeros(model_weights[layer_index].size())
    for client_index in range(S-1):
        model_avg_buffer += other_client_models[client_index][layer_index]
    model_avg_buffer += (ori_model_weights[layer_index]+S*epsilon[layer_index])
    averaged_model.append(model_avg_buffer/S)

# %%
for am_index, am in enumerate(averaged_model):
    print(am_index, torch.norm(averaged_model[am_index]-model_weights[am_index]).item())
# Out:
# 0 3.5357953720449586e-07
# 1 6.909541383492979e-08
# 2 7.11363270511356e-07
# 3 1.9698973119375296e-08
# 4 1.2455376463549328e-06
# 5 3.393346759139604e-08
# 6 7.027445576568425e-07
# 7 2.863438730571488e-08

# %%
avg_model = LeNet()

for avgm_index, avg_weight in enumerate(avg_model.parameters()):
    avg_weight.data = averaged_model[avgm_index]

# %%
test(model, device, test_loader, criterion)
# Out:
# #### Test set: Average loss: 0.0072, Accuracy: 16042/18800 (85%)
#
# Accuracy of 0 : 79.75
# Accuracy of 1 : 62.5
# Accuracy of 2 : 89.75
# Accuracy of 3 : 0.0
# Accuracy of 4 : 90.25
# Accuracy of 5 : 86.5
# Accuracy of 6 : 91.75
# Accuracy of 7 : 97.25
# Accuracy of 8 : 93.5
# Accuracy of 9 : 59.5
# Accuracy of 10 : 97.75
# Accuracy of 11 : 96.5
# Accuracy of 12 : 92.0
# Accuracy of 13 : 93.75
# Accuracy of 14 : 98.0
# Accuracy of 15 : 64.25
# Accuracy of 16 : 97.25
# Accuracy of 17 : 97.5
# Accuracy of 18 : 59.25
# Accuracy of 19 : 93.75
# Accuracy of 20 : 97.0
# Accuracy of 21 : 61.75
# Accuracy of 22 : 98.25
# Accuracy of 23 : 97.5
# Accuracy of 24 : 52.25
# Accuracy of 25 : 95.25
# Accuracy of 26 : 90.0
# Accuracy of 27 : 95.5
# Accuracy of 28 : 96.5
# Accuracy of 29 : 93.25
# Accuracy of 30 : 93.75
# Accuracy of 31 : 93.75
# Accuracy of 32 : 98.75
# Accuracy of 33 : 97.75
# Accuracy of 34 : 91.25
# Accuracy of 35 : 93.25
# Accuracy of 36 : 85.0
# Accuracy of 37 : 90.5
# Accuracy of 38 : 97.5
# Accuracy of 39 : 96.75
# Accuracy of 40 : 58.75
# Accuracy of 41 : 74.5
# Accuracy of 42 : 94.0
# Accuracy of 43 : 88.25
# Accuracy of 44 : 53.5
# Accuracy of 45 : 94.75
# Accuracy of 46 : 90.5
